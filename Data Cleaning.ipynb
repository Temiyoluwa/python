# %% [markdown]
# ## Data Cleanin in Pandas

# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\PRAISE\Downloads\Customer Call List.xlsx')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.at[15,'Last_Name']
# Out:
# 'Weasley'

# %%
df.first_valid_index()
# Out:
# 0

# %%
#removing duplicates
df = df.drop_duplicates()

# %%
#removing unwanted columns
df.drop(columns ='Not_Useful_Column', inplace = True )
# Out:
# C:\Users\PRAISE\AppData\Local\Temp\ipykernel_10304\1162206289.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns ='Not_Useful_Column', inplace = True )

# %%
#removing unwanted signs using strip/lstrip/rstrip
#df['Last_Name'] = df['Last_Name'].str.lstrip('...')
#df['Last_Name']=df['Last_Name'].str.lstrip('/')
#df['Last_Name']=df['Last_Name'].str.rstrip('_')
df['Last_Name'] = df['Last_Name'].str.strip('123./_')
df
# Out:
# C:\Users\PRAISE\AppData\Local\Temp\ipykernel_10304\1460478336.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Last_Name'] = df['Last_Name'].str.strip('123./_')
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df['Phone_Number']=df['Phone_Number'].str.replace('[^a-zA-Z0-9]','')
df
# Out:
# C:\Users\PRAISE\AppData\Local\Temp\ipykernel_10304\430231681.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Phone_Number']=df['Phone_Number'].str.replace('[^a-zA-Z0-9]','')
# C:\Users\PRAISE\AppData\Local\Temp\ipykernel_10304\430231681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone_Number']=df['Phone_Number'].str.replace('[^a-zA-Z0-9]','')
#     CustomerID First_Name   Last_Name Phone_Number  \
# 0         1001      Frodo     Baggins   1235455421
# 1         1002       Abed       Nadir   1236439775
# 2         1003     Walter       White          NaN
# 3         1004     Dwight     Schrute   1235432345
# 4         1005        Jon        Snow   8766783469
# ...

# %%
#df['Phone_Number'].apply(lambda x: x[0:3]+ '-' + x[3:6] + '-' + x[6:10])
#this is the main step, but because the phone_number column contains str it will not work

#hence we yurn it into a str first
#df['Phone_Number']= df['Phone_Number'].apply(lambda x: str(x))

#then run the main step again
#df['Phone_Number'] = df['Phone_Number'].apply(lambda x: x[0:3]+ '-' + x[3:6] + '-' + x[6:10])

#then remove the unwanted string values
df['Phone_Number'] = df['Phone_Number'].str.replace('nan--', '')
df['Phone_Number'] = df['Phone_Number'].str.replace('Na--','')

df
# Out:
# C:\Users\PRAISE\AppData\Local\Temp\ipykernel_10304\4263293472.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone_Number'] = df['Phone_Number'].str.replace('nan--', '')
# C:\Users\PRAISE\AppData\Local\Temp\ipykernel_10304\4263293472.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Phone_Number'] = df['Phone_Number'].str.replace('Na--','')
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df[['Street_address', 'State', 'Zip_Code']] = df['Address'].str.split(',',2, expand= True)
df
# Out:
# C:\Users\PRAISE\AppData\Local\Temp\ipykernel_10304\1426142964.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['Street_address', 'State', 'Zip_Code']] = df['Address'].str.split(',',2, expand= True)
# C:\Users\PRAISE\AppData\Local\Temp\ipykernel_10304\1426142964.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Street_address', 'State', 'Zip_Code']] = df['Address'].str.split(',',2, expand= True)
# C:\Users\PRAISE\AppData\Local\Temp\ipykernel_10304\1426142964.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df['Paying Customer'] = df['Paying Customer'].str.replace ('Yes', 'Y')
df['Paying Customer'] = df['Paying Customer'].str.replace ('No', 'N')
df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace ('No', 'N')
df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace ('Yes', 'Y')
df
# Out:
# C:\Users\PRAISE\AppData\Local\Temp\ipykernel_10304\2499248545.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Paying Customer'] = df['Paying Customer'].str.replace ('Yes', 'Y')
# C:\Users\PRAISE\AppData\Local\Temp\ipykernel_10304\2499248545.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Paying Customer'] = df['Paying Customer'].str.replace ('No', 'N')
# C:\Users\PRAISE\AppData\Local\Temp\ipykernel_10304\2499248545.py:3: SettingWithCopyWarning:
# ...

# %%
df = df.replace('N/a','')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df=df.fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
for x in df.index:
    if df.loc[x,'Do_Not_Contact'] =='Y':
        df.drop(x, inplace = True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 2         1003     Walter       White
# 4         1005        Jon        Snow  876-678-3469
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# ...

# %%
for x in df.index:
    if df.loc[x,'Phone_Number'] == '':
        df.drop(x, inplace = True)
    
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 4         1005        Jon        Snow  876-678-3469
# 7         1008   Sherlock      Holmes  876-678-3469
# 9         1010      Peter      Parker  123-545-5421
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 4                 123 Dragons Road               Y              N
# 7                    98 Clue Drive               N              N
# 9       25th Main Street, New York               Y              N
# ...

# %%
df.reset_index(drop = True)
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number  \
# 0        1001      Frodo     Baggins  123-545-5421
# 1        1005        Jon        Snow  876-678-3469
# 2        1008   Sherlock      Holmes  876-678-3469
# 3        1010      Peter      Parker  123-545-5421
# 4        1013        Don      Draper  123-543-2345
# 5        1014     Leslie       Knope  876-678-3469
# 6        1015       Toby  Flenderson  304-762-2467
# 7        1016        Ron     Weasley  123-545-5421
# 8        1017   Michael        Scott  123-643-9775
# 9        1020     Anakin   Skywalker  876-678-3469
#
#                           Address Paying Customer Do_Not_Contact  \
# 0           123 Shire Lane, Shire               Y              N
# 1                123 Dragons Road               Y              N
# 2                   98 Clue Drive               N              N
# 3      25th Main Street, New York               Y              N
# 4                2039 Main Street               Y              N
# ...

# %%
ig1.fillna('')
# Out:
#                              Date            Post ID    Network Post Type  \
# Content Type
# Carousel        1/30/2023 5:06 pm  18216468940204235  Instagram      Post
# Photo           4/15/2022 9:04 am  17971531720518163  Instagram      Post
# Video           5/28/2021 8:45 pm  18008486986321009  Instagram      Post
# Carousel         1/4/2023 4:08 pm  17903404469640387  Instagram      Post
# Photo           12/7/2021 6:52 pm  17950858072558814  Instagram      Post
# ...                           ...                ...        ...       ...
# Photo          12/24/2014 5:37 pm  17841808444024797  Instagram      Post
# Photo         12/24/2014 10:28 am  17841674617024797  Instagram      Post
# Photo          12/23/2014 5:14 pm  17842896850024797  Instagram      Post
# Photo         12/23/2014 10:38 am  17841674620024797  Instagram      Post
# Photo          12/22/2014 5:59 pm  17841808438024797  Instagram      Post
#
#                   Profile        Sent by  \
# Content Type
# ...

# %%
import pandas as pd

# %%
ig1=pd.read_csv(r'C:\Users\PRAISE\Downloads\January1 - July 13_ 2023_Instagram.csv', low_memory= False)

# %%
ig1 = ig1.drop_duplicates()

# %%
ig1[['Date','Time']] = ig1['Date'].str.split(' ',1, expand= True) 
ig1
# Out:
# C:\Users\PRAISE\AppData\Local\Temp\ipykernel_11108\2929621368.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   ig1[['Date','Time']] = ig1['Date'].str.split(' ',1, expand= True)
#             Date            Post ID    Network Post Type Content Type  \
# 0      1/30/2023  18216468940204235  Instagram      Post     Carousel
# 1      4/15/2022  17971531720518163  Instagram      Post        Photo
# 2      5/28/2021  18008486986321009  Instagram      Post        Video
# 3       1/4/2023  17903404469640387  Instagram      Post     Carousel
# 4      12/7/2021  17950858072558814  Instagram      Post        Photo
# ...          ...                ...        ...       ...          ...
# 9995  12/24/2014  17841808444024797  Instagram      Post        Photo
# 9996  12/24/2014  17841674617024797  Instagram      Post        Photo
# 9997  12/23/2014  17842896850024797  Instagram      Post        Photo
# ...

# %%
pd.set_option('display.max.columns',150)
pd.set_option('display.max.rows', 100)
# Out:
# KeyboardInterrupt

# %%
#ig1 = ig1.fillna('')
ig1
# Out:
#      Content Type        Date            Post ID    Network Post Type  \
# 0        Carousel   1/30/2023  18216468940204235  Instagram      Post
# 1           Photo   4/15/2022  17971531720518163  Instagram      Post
# 2           Video   5/28/2021  18008486986321009  Instagram      Post
# 3        Carousel    1/4/2023  17903404469640387  Instagram      Post
# 4           Photo   12/7/2021  17950858072558814  Instagram      Post
# ...           ...         ...                ...        ...       ...
# 9995        Photo  12/24/2014  17841808444024797  Instagram      Post
# 9996        Photo  12/24/2014  17841674617024797  Instagram      Post
# 9997        Photo  12/23/2014  17842896850024797  Instagram      Post
# 9998        Photo  12/23/2014  17841674620024797  Instagram      Post
# 9999        Photo  12/22/2014  17841808438024797  Instagram      Post
#
#           Profile        Sent by                                      Link  \
# ...

# %%
#ig = ig1.set_index(['Content Type', 'Date'])
ig.sort_index()
#ig =ig.reset_index()
ig
# Out:
#                                    Post ID    Network Post Type      Profile  \
# Content Type Date
# Carousel     1/30/2023   18216468940204235  Instagram      Post  stanbicibtc
# Photo        4/15/2022   17971531720518163  Instagram      Post  stanbicibtc
# Video        5/28/2021   18008486986321009  Instagram      Post  stanbicibtc
# Carousel     1/4/2023    17903404469640387  Instagram      Post  stanbicibtc
# Photo        12/7/2021   17950858072558814  Instagram      Post  stanbicibtc
# ...                                    ...        ...       ...          ...
#              12/24/2014  17841808444024797  Instagram      Post  stanbicibtc
#              12/24/2014  17841674617024797  Instagram      Post  stanbicibtc
#              12/23/2014  17842896850024797  Instagram      Post  stanbicibtc
#              12/23/2014  17841674620024797  Instagram      Post  stanbicibtc
#              12/22/2014  17841808438024797  Instagram      Post  stanbicibtc
#
# ...

# %%
ig1.drop_index_col
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 ig1.drop_index_col
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'drop_index_col'

# %%
for x in ig1:
    if ig1[x,'Impressions'] =='':
        drop(x, inplace == True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Date', 'Impressions')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
ig.set_index(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[171], line 1
# ----> 1 ig.set_index(1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'set_index'

# %%
ig1['Linked Content']= ig1['Linked Content'].apply(lambda x: str(x))
ig1['Linked Content'].str.replace('nan','')
# Out:
# Content Type
# Carousel
# Photo
# Video
# Carousel
# Photo
#            ..
# Photo
# Photo
# Photo
# Photo
# Photo
# Name: Linked Content, Length: 10000, dtype: object

# %%
ig1['Profile']
# Out:
# Content Type
# Carousel    stanbicibtc
# Photo       stanbicibtc
# Video       stanbicibtc
# Carousel    stanbicibtc
# Photo       stanbicibtc
#                ...
# Photo       stanbicibtc
# Photo       stanbicibtc
# Photo       stanbicibtc
# Photo       stanbicibtc
# Photo       stanbicibtc
# Name: Profile, Length: 10000, dtype: object

# %%
ig1.columns
# Out:
# Index(['Date', 'Post ID', 'Network', 'Post Type', 'Profile', 'Sent by', 'Link',
#        'Post', 'Linked Content', 'Impressions',
#        ...
#        'Video Removed from Playlists', 'Annotation Impressions',
#        'Annotation Clickable Impressions', 'Annotation Closable Impressions',
#        'Annotation Closes', 'Card Impressions', 'Card Teaser Impressions',
#        'Card Teaser Clicks', 'Poll Votes', 'Tags'],
#       dtype='object', length=146)

# %% [markdown]
# ## Personal Project

# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\PRAISE\Downloads\xlsx files\Nashville Housing Data for Data Cleaning.xlsx')

# %%
df
# Out:
#        UniqueID           ParcelID                  LandUse  \
# 0           2045   007 00 0 125.00            SINGLE FAMILY
# 1          16918   007 00 0 130.00            SINGLE FAMILY
# 2          54582   007 00 0 138.00            SINGLE FAMILY
# 3          43070   007 00 0 143.00            SINGLE FAMILY
# 4          22714   007 00 0 149.00            SINGLE FAMILY
# ...          ...               ...                      ...
# 56472      30469  188 10 0A 101.00            SINGLE FAMILY
# 56473      27707  188 10 0A 107.00            SINGLE FAMILY
# 56474      52709  188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 56475      54042  188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress   SaleDate  SalePrice  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000
# ...

# %%
df.LandUse.first_valid_index()
# Out:
# 0

# %%
df.first_valid_index()
# Out:
# 0

# %%
df.LandUse.count()
# Out:
# 56477

# %%
df.LandUse
# Out:
# 0                  SINGLE FAMILY
# 1                  SINGLE FAMILY
# 2                  SINGLE FAMILY
# 3                  SINGLE FAMILY
# 4                  SINGLE FAMILY
#                   ...
# 56472              SINGLE FAMILY
# 56473              SINGLE FAMILY
# 56474    VACANT RESIDENTIAL LAND
# 56475    VACANT RESIDENTIAL LAND
# 56476    VACANT RESIDENTIAL LAND
# Name: LandUse, Length: 56477, dtype: object

# %%
df['SaleDate'].unique
# Out:
# <bound method Series.unique of 0       2013-04-09
# 1       2014-06-10
# 2       2016-09-26
# 3       2016-01-29
# 4       2014-10-10
#            ...
# 56472   2015-05-27
# 56473   2015-03-02
# 56474   2016-08-16
# 56475   2016-09-07
# 56476   2016-09-07
# Name: SaleDate, Length: 56477, dtype: datetime64[ns]>

# %%
df.notnull().count()
# Out:
# UniqueID           56477
# ParcelID           56477
# LandUse            56477
# PropertyAddress    56477
# SaleDate           56477
# SalePrice          56477
# LegalReference     56477
# SoldAsVacant       56477
# OwnerName          56477
# OwnerAddress       56477
# Acreage            56477
# TaxDistrict        56477
# LandValue          56477
# BuildingValue      56477
# TotalValue         56477
# YearBuilt          56477
# Bedrooms           56477
# FullBath           56477
# HalfBath           56477
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.count()
# Out:
# UniqueID           56477
# ParcelID           56477
# LandUse            56477
# PropertyAddress    56448
# SaleDate           56477
# SalePrice          56477
# LegalReference     56477
# SoldAsVacant       56477
# OwnerName          25261
# OwnerAddress       26015
# Acreage            26015
# TaxDistrict        26015
# LandValue          26015
# BuildingValue      26015
# TotalValue         26015
# YearBuilt          24163
# Bedrooms           24157
# FullBath           24275
# HalfBath           24144
# dtype: int64

# %%
df.describe()
# Out:
#           UniqueID      SalePrice       Acreage     LandValue  BuildingValue  \
# count  56477.000000  5.647700e+04  26015.000000  2.601500e+04   2.601500e+04
# mean   28334.001133  3.272264e+05      0.498923  6.906856e+04   1.607847e+05
# std    16352.590651  9.298326e+05      1.570454  1.060401e+05   2.067999e+05
# min        0.000000  5.000000e+01      0.010000  1.000000e+02   0.000000e+00
# 25%    14186.000000  1.350000e+05      0.180000  2.100000e+04   7.590000e+04
# 50%    28313.000000  2.051000e+05      0.270000  2.880000e+04   1.114000e+05
# 75%    42513.000000  3.285000e+05      0.450000  6.000000e+04   1.807000e+05
# max    56635.000000  5.427806e+07    160.060000  2.772000e+06   1.297180e+07
#
#          TotalValue     YearBuilt      Bedrooms      FullBath      HalfBath
# count  2.601500e+04  24163.000000  24157.000000  24275.000000  24144.000000
# mean   2.323754e+05   1963.744899      3.089912      1.886014      0.283921
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56477 entries, 0 to 56476
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UniqueID         56477 non-null  int64
#  1   ParcelID         56477 non-null  object
#  2   LandUse          56477 non-null  object
#  3   PropertyAddress  56448 non-null  object
#  4   SaleDate         56477 non-null  datetime64[ns]
#  5   SalePrice        56477 non-null  int64
#  6   LegalReference   56477 non-null  object
#  7   SoldAsVacant     56477 non-null  object
#  8   OwnerName        25261 non-null  object
#  9   OwnerAddress     26015 non-null  object
#  10  Acreage          26015 non-null  float64
#  11  TaxDistrict      26015 non-null  object
#  12  LandValue        26015 non-null  float64
#  13  BuildingValue    26015 non-null  float64
#  14  TotalValue       26015 non-null  float64
#  15  YearBuilt        24163 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['UniqueID ', 'ParcelID', 'LandUse', 'PropertyAddress', 'SaleDate',
#        'SalePrice', 'LegalReference', 'SoldAsVacant', 'OwnerName',
#        'OwnerAddress', 'Acreage', 'TaxDistrict', 'LandValue', 'BuildingValue',
#        'TotalValue', 'YearBuilt', 'Bedrooms', 'FullBath', 'HalfBath'],
#       dtype='object')

# %%
pd.set_option('display.max.rows', 20)

df['LandUse'].unique()
# Out:
# array(['SINGLE FAMILY', 'RESIDENTIAL CONDO', 'VACANT RURAL LAND',
#        'VACANT RES LAND', 'DUPLEX', 'VACANT RESIDENTIAL LAND', 'CHURCH',
#        'ZERO LOT LINE', 'RESIDENTIAL COMBO/MISC', 'PARSONAGE',
#        'OFFICE BLDG (ONE OR TWO STORIES)',
#        'GREENBELT/RES_x000D_\nGRRENBELT/RES', 'MOBILE HOME',
#        'PARKING LOT', 'CLUB/UNION HALL/LODGE', 'TRIPLEX',
#        'VACANT ZONED MULTI FAMILY', 'SPLIT CLASS', 'CONDO', 'QUADPLEX',
#        'LIGHT MANUFACTURING', 'FOREST', 'CONVENIENCE MARKET WITHOUT GAS',
#        'DORMITORY/BOARDING HOUSE', 'GREENBELT', 'DAY CARE CENTER',
#        'METRO OTHER THAN OFC, SCHOOL,HOSP, OR PARK',
#        'TERMINAL/DISTRIBUTION WAREHOUSE', 'NIGHTCLUB/LOUNGE',
#        'RESTURANT/CAFETERIA', 'VACANT COMMERCIAL LAND',
#        'CONDOMINIUM OFC  OR OTHER COM CONDO', 'STRIP SHOPPING CENTER',
#        'VACANT RESIENTIAL LAND', 'APARTMENT: LOW RISE (BUILT SINCE 1960)',
#        'ONE STORY GENERAL RETAIL STORE', 'NON-PROFIT CHARITABLE SERVICE',
# ...

# %% [markdown]
# ### Checking if the Landuse rows have similar data

# %%
vacant= ['VACANT RESIDENTIAL LAND','VACANT RES LAND']
df[df['LandUse'].isin(vacant)].sort_values(by = 'SaleDate', ascending = True)

#df[df['LandUse'].str.contains('VACANT RES LAND')]
# Out:
#        UniqueID           ParcelID                  LandUse  \
# 15358        298   083 05 0 450.00          VACANT RES LAND
# 35653        153  128 12 0C 049.00          VACANT RES LAND
# 55886         82  182 12 0A 148.00          VACANT RES LAND
# 55880         81  182 12 0A 145.00          VACANT RES LAND
# 30072        365  110 03 0A 054.00          VACANT RES LAND
# ...          ...               ...                      ...
# 32134      55719   117 07 0 112.00  VACANT RESIDENTIAL LAND
# 11350      56353   075 11 0 060.00  VACANT RESIDENTIAL LAND
# 39194      56477   135 00 0 295.00  VACANT RESIDENTIAL LAND
# 19855      55558   092 03 0 116.00  VACANT RESIDENTIAL LAND
# 51255      55456  172 03 0A 125.00  VACANT RESIDENTIAL LAND
#
#                              PropertyAddress   SaleDate  SalePrice  \
# 15358              800  N 14TH ST, NASHVILLE 2013-01-02      72500
# 35653     1123  WOODBURY FALLS CT, NASHVILLE 2013-01-04     194000
# ...

# %%
name=['FREEDMAN, RYAN J.']

# %%
df[df['OwnerName'].isin(name)]
# Out:
#        UniqueID          ParcelID          LandUse            PropertyAddress  \
# 15358        298  083 05 0 450.00  VACANT RES LAND  800  N 14TH ST, NASHVILLE
# 15359       8101  083 05 0 450.00    SINGLE FAMILY  800  N 14TH ST, NASHVILLE
#
#         SaleDate  SalePrice    LegalReference SoldAsVacant          OwnerName  \
# 15358 2013-01-02      72500  20130107-0001758           No  FREEDMAN, RYAN J.
# 15359 2013-09-03     507235  20130904-0093001           No  FREEDMAN, RYAN J.
#
#                         OwnerAddress  Acreage              TaxDistrict  \
# 15358  800  N 14TH ST, NASHVILLE, TN     0.15  URBAN SERVICES DISTRICT
# 15359  800  N 14TH ST, NASHVILLE, TN     0.15  URBAN SERVICES DISTRICT
#
#        LandValue  BuildingValue  TotalValue  YearBuilt  Bedrooms  FullBath  \
# 15358    60000.0       368200.0    459800.0     2013.0       5.0       3.0
# 15359    60000.0       368200.0    459800.0     2013.0       5.0       3.0
#
#        HalfBath
# 15358       1.0
# ...

# %% [markdown]
# ### it is possible this guy sold the same property twice

# %%
aa = df[df['LandUse'].str.contains('VACANT RESIDENTIAL LAND')]
aa.count()
# Out:
# UniqueID           3547
# ParcelID           3547
# LandUse            3547
# PropertyAddress    3542
# SaleDate           3547
# SalePrice          3547
# LegalReference     3547
# SoldAsVacant       3547
# OwnerName          1103
# OwnerAddress       1245
# Acreage            1245
# TaxDistrict        1245
# LandValue          1245
# BuildingValue      1245
# TotalValue         1245
# YearBuilt           270
# Bedrooms            274
# FullBath            366
# HalfBath            348
# dtype: int64

# %%
aa = df[df['LandUse'].str.contains('VACANT RESIENTIAL LAND')]
aa.count()
# Out:
# UniqueID           3
# ParcelID           3
# LandUse            3
# PropertyAddress    3
# SaleDate           3
# SalePrice          3
# LegalReference     3
# SoldAsVacant       3
# OwnerName          3
# OwnerAddress       3
# Acreage            3
# TaxDistrict        3
# LandValue          3
# BuildingValue      3
# TotalValue         3
# YearBuilt          0
# Bedrooms           0
# FullBath           0
# HalfBath           0
# dtype: int64

# %%
df.count()
# Out:
# UniqueID           56477
# ParcelID           56477
# LandUse            56477
# PropertyAddress    56448
# SaleDate           56477
# SalePrice          56477
# LegalReference     56477
# SoldAsVacant       56477
# OwnerName          25261
# OwnerAddress       26015
# Acreage            26015
# TaxDistrict        26015
# LandValue          26015
# BuildingValue      26015
# TotalValue         26015
# YearBuilt          24163
# Bedrooms           24157
# FullBath           24275
# HalfBath           24144
# dtype: int64

# %%
df['LandUse'] = df['LandUse'].replace('VACANT RES LAND','VACANT RESIDENTIAL LAND')

# %%
df[df['LandUse'].str.contains('VACANT RESIENTIAL LAND')]
# Out:
#        UniqueID          ParcelID                 LandUse  \
# 17696      31640  087 02 0 083.00  VACANT RESIENTIAL LAND
# 46712      30909  158 00 0 119.00  VACANT RESIENTIAL LAND
# 46713      40470  158 00 0 119.00  VACANT RESIENTIAL LAND
#
#                          PropertyAddress   SaleDate  SalePrice  \
# 17696          0  RACCOON TRL, HERMITAGE 2015-05-22     220000
# 46712  1627  OLD HICKORY BLVD, BRENTWOOD 2015-05-22     230000
# 46713  1627  OLD HICKORY BLVD, BRENTWOOD 2015-11-20     607642
#
#          LegalReference SoldAsVacant  \
# 17696  20150529-0049626           No
# 46712  20150602-0051451          Yes
# 46713  20151201-0121075           No
#
#                                        OwnerName  \
# 17696  PROGRESS RESIDENTIAL 2015-3 BORROWER, LLC
# 46712         WILSON, JARED J. & KENDAL BRINKLEY
# 46713         WILSON, JARED J. & KENDAL BRINKLEY
#
#                                 OwnerAddress  Acreage  \
# 17696          0  RACCOON TRL, HERMITAGE, TN     0.46
# ...

# %%
vacant= ['VACANT RESIENTIAL LAND']

# %%
df[df['LandUse'].isin(vacant)]
# Out:
#        UniqueID          ParcelID                 LandUse  \
# 17696      31640  087 02 0 083.00  VACANT RESIENTIAL LAND
# 46712      30909  158 00 0 119.00  VACANT RESIENTIAL LAND
# 46713      40470  158 00 0 119.00  VACANT RESIENTIAL LAND
#
#                          PropertyAddress   SaleDate  SalePrice  \
# 17696          0  RACCOON TRL, HERMITAGE 2015-05-22     220000
# 46712  1627  OLD HICKORY BLVD, BRENTWOOD 2015-05-22     230000
# 46713  1627  OLD HICKORY BLVD, BRENTWOOD 2015-11-20     607642
#
#          LegalReference SoldAsVacant  \
# 17696  20150529-0049626           No
# 46712  20150602-0051451          Yes
# 46713  20151201-0121075           No
#
#                                        OwnerName  \
# 17696  PROGRESS RESIDENTIAL 2015-3 BORROWER, LLC
# 46712         WILSON, JARED J. & KENDAL BRINKLEY
# 46713         WILSON, JARED J. & KENDAL BRINKLEY
#
#                                 OwnerAddress  Acreage  \
# 17696          0  RACCOON TRL, HERMITAGE, TN     0.46
# ...

# %%
df['LandUse'] = df['LandUse'].str.replace('GREENBELT/RES_x000D_\nGRRENBELT/RES', 'GREENBELT')

# %%
df['LandUse'] = df['LandUse'].str.replace('VACANT RESIENTIAL LAND','VACANT RESIDENTIAL LAND')

# %%
df['LandUse'].unique()
# Out:
# array(['SINGLE FAMILY', 'RESIDENTIAL CONDO', 'VACANT RURAL LAND',
#        'VACANT RESIDENTIAL LAND', 'DUPLEX', 'CHURCH', 'ZERO LOT LINE',
#        'RESIDENTIAL COMBO/MISC', 'PARSONAGE',
#        'OFFICE BLDG (ONE OR TWO STORIES)', 'GREENBELT', 'MOBILE HOME',
#        'PARKING LOT', 'CLUB/UNION HALL/LODGE', 'TRIPLEX',
#        'VACANT ZONED MULTI FAMILY', 'SPLIT CLASS', 'CONDO', 'QUADPLEX',
#        'LIGHT MANUFACTURING', 'FOREST', 'CONVENIENCE MARKET WITHOUT GAS',
#        'DORMITORY/BOARDING HOUSE', 'DAY CARE CENTER',
#        'METRO OTHER THAN OFC, SCHOOL,HOSP, OR PARK',
#        'TERMINAL/DISTRIBUTION WAREHOUSE', 'NIGHTCLUB/LOUNGE',
#        'RESTURANT/CAFETERIA', 'VACANT COMMERCIAL LAND',
#        'CONDOMINIUM OFFICE', 'STRIP SHOPPING CENTER',
#        'APARTMENT: LOW RISE (BUILT SINCE 1960)',
#        'ONE STORY GENERAL RETAIL STORE', 'NON-PROFIT CHARITABLE SERVICE',
#        'SMALL SERVICE SHOP', 'MORTUARY/CEMETERY'], dtype=object)

# %%
df['LandUse'] = df['LandUse'].str.replace('CONDOMINIUM OFC  OR OTHER COM CONDO','CONDOMINIUM OFFICE')

# %%
df['LandUse'] = df['LandUse'].str.replace('CONDOMINIUM OFC  OR OTHER COM CONDO','CONDOMINIUM OFFICE')

# %%
df[df['LandUse'].str.contains('STRIP SHOPPING CENTER')]
df['LandUse'] = df['LandUse'].str.replace('STRIP SHOPPING CENTER','SHOPPING CENTER')

# %%
df['LandUse']= df['LandUse'].str.replace('OFFICE BLDG (ONE OR TWO STORIES)','OFFICE BUILDING')
# Out:
# C:\Users\PRAISE\AppData\Local\Temp\ipykernel_10120\942015516.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['LandUse']= df['LandUse'].str.replace('OFFICE BLDG (ONE OR TWO STORIES)','OFFICE BUILDING')

# %%
df['LandUse'].unique()
# Out:
# array(['SINGLE FAMILY', 'RESIDENTIAL CONDO', 'VACANT RURAL LAND',
#        'VACANT RESIDENTIAL LAND', 'DUPLEX', 'CHURCH', 'ZERO LOT LINE',
#        'RESIDENTIAL COMBO/MISC', 'PARSONAGE',
#        'OFFICE BLDG (ONE OR TWO STORIES)', 'GREENBELT', 'MOBILE HOME',
#        'PARKING LOT', 'CLUB/UNION HALL/LODGE', 'TRIPLEX',
#        'VACANT ZONED MULTI FAMILY', 'SPLIT CLASS', 'CONDO', 'QUADPLEX',
#        'LIGHT MANUFACTURING', 'FOREST', 'CONVENIENCE MARKET WITHOUT GAS',
#        'DORMITORY/BOARDING HOUSE', 'DAY CARE CENTER',
#        'METRO OTHER THAN OFC, SCHOOL,HOSP, OR PARK',
#        'TERMINAL/DISTRIBUTION WAREHOUSE', 'NIGHTCLUB/LOUNGE',
#        'RESTURANT/CAFETERIA', 'VACANT COMMERCIAL LAND',
#        'CONDOMINIUM OFFICE', 'SHOPPING CENTER',
#        'APARTMENT: LOW RISE (BUILT SINCE 1960)',
#        'ONE STORY GENERAL RETAIL STORE', 'NON-PROFIT CHARITABLE SERVICE',
#        'SMALL SERVICE SHOP', 'MORTUARY/CEMETERY'], dtype=object)

# %%
df[df['LandUse'].str.contains('ONE STORY GENERAL RETAIL STORE')]
# Out:
#        UniqueID          ParcelID                         LandUse  \
# 20640      25292  093 04 0 050.00  ONE STORY GENERAL RETAIL STORE
#
#                   PropertyAddress   SaleDate  SalePrice    LegalReference  \
# 20640  608  SHELBY AVE, NASHVILLE 2014-12-15     258000  20141215-0114517
#
#       SoldAsVacant                               OwnerName  \
# 20640           No  NASHVILLE REAL ESTATE INVESTMENTS, LLC
#
#                          OwnerAddress  Acreage              TaxDistrict  \
# 20640  608  SHELBY AVE, NASHVILLE, TN      0.3  URBAN SERVICES DISTRICT
#
#        LandValue  BuildingValue  TotalValue  YearBuilt  Bedrooms  FullBath  \
# 20640    63000.0       134500.0    203200.0     1925.0       0.0       0.0
#
#        HalfBath
# 20640       0.0

# %%
df['LandUse'] = df['LandUse'].str.replace('OFFICE BLDG (ONE OR TWO STORIES)','OFFICE BUILDING')
#df[df['LandUse'].str.contains('ONE OR TWO STORIES')]
# Out:
# C:\Users\PRAISE\AppData\Local\Temp\ipykernel_10120\1416024403.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['LandUse'] = df['LandUse'].str.replace('OFFICE BLDG (ONE OR TWO STORIES)','OFFICE BUILDING')

# %%
df[df['LandUse'].str.contains('OFFICE BUILDING
# Out:
# Empty DataFrame
# Columns: [UniqueID , ParcelID, LandUse, PropertyAddress, SaleDate, SalePrice, LegalReference, SoldAsVacant, OwnerName, OwnerAddress, Acreage, TaxDistrict, LandValue, BuildingValue, TotalValue, YearBuilt, Bedrooms, FullBath, HalfBath]
# Index: []

# %%
df[df.duplicated()]
df
# Out:
#        UniqueID           ParcelID                  LandUse  \
# 0           2045   007 00 0 125.00            SINGLE FAMILY
# 1          16918   007 00 0 130.00            SINGLE FAMILY
# 2          54582   007 00 0 138.00            SINGLE FAMILY
# 3          43070   007 00 0 143.00            SINGLE FAMILY
# 4          22714   007 00 0 149.00            SINGLE FAMILY
# ...          ...               ...                      ...
# 56472      30469  188 10 0A 101.00            SINGLE FAMILY
# 56473      27707  188 10 0A 107.00            SINGLE FAMILY
# 56474      52709  188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 56475      54042  188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress   SaleDate  SalePrice  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000
# ...

# %%
#df['PropertyAddress'].mask(df['OwnerAddress']).isna(),df['PropertyAddress']

#df['OwnerAddress'] = df['OwnerAddress'].fillna('')
#for x in df.index:
#    if df.loc[x,'PropertyAddress'] != df['OwnerAddress']:
#        df['PropertyAddress'] = df.replace(x,df['OwnerAddress'])
        
#df
#df [‘PropertyAddress’] = df [‘PropertyAddress’].where (df [‘PropertyAddress’] == df [‘OwnerAddress’], df [‘OwnerAddress’])
#df = pd.read_excel(r'C:\Users\PRAISE\Downloads\xlsx files\Nashville Housing Data for Data Cleaning.xlsx')
df['OwnerAddress'].where (df ['PropertyAddress'] == df ['OwnerAddress'], df ['PropertyAddress'])
# Out:
# 0         1808  FOX CHASE DR, GOODLETTSVILLE
# 1         1832  FOX CHASE DR, GOODLETTSVILLE
# 2         1864 FOX CHASE  DR, GOODLETTSVILLE
# 3         1853  FOX CHASE DR, GOODLETTSVILLE
# 4         1829  FOX CHASE DR, GOODLETTSVILLE
#                         ...
# 56472    1435  WINDING CREEK DR, NOLENSVILLE
# 56473    1423  WINDING CREEK DR, NOLENSVILLE
# 56474      1804 GRACE POINT  LN, NOLENSVILLE
# 56475     1709 PARK TERRACE  LN, NOLENSVILLE
# 56476     1713 PARK TERRACE  LN, NOLENSVILLE
# Name: OwnerAddress, Length: 56477, dtype: object

# %%
df
# Out:
#        UniqueID           ParcelID                  LandUse  \
# 0           2045   007 00 0 125.00            SINGLE FAMILY
# 1          16918   007 00 0 130.00            SINGLE FAMILY
# 2          54582   007 00 0 138.00            SINGLE FAMILY
# 3          43070   007 00 0 143.00            SINGLE FAMILY
# 4          22714   007 00 0 149.00            SINGLE FAMILY
# ...          ...               ...                      ...
# 56472      30469  188 10 0A 101.00            SINGLE FAMILY
# 56473      27707  188 10 0A 107.00            SINGLE FAMILY
# 56474      52709  188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 56475      54042  188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                               PropertyAddress   SaleDate  SalePrice  \
# 0      1808  FOX CHASE DR, GOODLETTSVILLE, TN 2013-04-09     240000
# 1      1832  FOX CHASE DR, GOODLETTSVILLE, TN 2014-06-10     366000
# ...

# %%
df
# Out:
#        UniqueID           ParcelID                  LandUse  \
# 0           2045   007 00 0 125.00            SINGLE FAMILY
# 1          16918   007 00 0 130.00            SINGLE FAMILY
# 2          54582   007 00 0 138.00            SINGLE FAMILY
# 3          43070   007 00 0 143.00            SINGLE FAMILY
# 4          22714   007 00 0 149.00            SINGLE FAMILY
# ...          ...               ...                      ...
# 56472      30469  188 10 0A 101.00            SINGLE FAMILY
# 56473      27707  188 10 0A 107.00            SINGLE FAMILY
# 56474      52709  188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 56475      54042  188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress   SaleDate  SalePrice  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000
# ...

# %%
df[df['LandUse'].isin(lists)]
# Out:
#        UniqueID          ParcelID                           LandUse  \
# 1544       43128  042 11 0 030.00  OFFICE BLDG (ONE OR TWO STORIES)
# 13981      14919  082 09 0 254.00  OFFICE BLDG (ONE OR TWO STORIES)
#
#                       PropertyAddress   SaleDate  SalePrice    LegalReference  \
# 1544   632  OLD HICKORY BLVD, MADISON 2016-01-19     225000  20160121-0006356
# 13981       707  MONROE ST, NASHVILLE 2014-04-24     520000  20140502-0037596
#
#       SoldAsVacant                 OwnerName  \
# 1544            No  J.E.T. PRODUCTIONS, INC.
# 13981           No    CROSSROADS CAMPUS, THE
#
#                              OwnerAddress  Acreage                TaxDistrict  \
# 1544   632  OLD HICKORY BLVD, MADISON, TN     0.87  GENERAL SERVICES DISTRICT
# 13981       707  MONROE ST, NASHVILLE, TN     0.18    URBAN SERVICES DISTRICT
#
#        LandValue  BuildingValue  TotalValue  YearBuilt  Bedrooms  FullBath  \
# ...

# %%
df[df['LandUse'].str.extract('OFFICE BLDG (ONE OR TWO STORIES)')]
# Out:
#        UniqueID  ParcelID LandUse PropertyAddress SaleDate  SalePrice  \
# 0            NaN      NaN     NaN             NaN      NaT        NaN
# 1            NaN      NaN     NaN             NaN      NaT        NaN
# 2            NaN      NaN     NaN             NaN      NaT        NaN
# 3            NaN      NaN     NaN             NaN      NaT        NaN
# 4            NaN      NaN     NaN             NaN      NaT        NaN
# ...          ...      ...     ...             ...      ...        ...
# 56472        NaN      NaN     NaN             NaN      NaT        NaN
# 56473        NaN      NaN     NaN             NaN      NaT        NaN
# 56474        NaN      NaN     NaN             NaN      NaT        NaN
# 56475        NaN      NaN     NaN             NaN      NaT        NaN
# 56476        NaN      NaN     NaN             NaN      NaT        NaN
#
#       LegalReference SoldAsVacant OwnerName OwnerAddress  Acreage TaxDistrict  \
# ...

# %%
for x in df.index:
    if df.loc[x,'LandUse'] == 'OFFICE BLDG (ONE OR TWO STORIES)':
        df.drop(x, inplace = True)
        
df
# Out:
#        UniqueID           ParcelID                  LandUse  \
# 0           2045   007 00 0 125.00            SINGLE FAMILY
# 1          16918   007 00 0 130.00            SINGLE FAMILY
# 2          54582   007 00 0 138.00            SINGLE FAMILY
# 3          43070   007 00 0 143.00            SINGLE FAMILY
# 4          22714   007 00 0 149.00            SINGLE FAMILY
# ...          ...               ...                      ...
# 56472      30469  188 10 0A 101.00            SINGLE FAMILY
# 56473      27707  188 10 0A 107.00            SINGLE FAMILY
# 56474      52709  188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 56475      54042  188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress   SaleDate  SalePrice  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000
# ...

# %%
df['LandUse'].unique()
# Out:
# array(['SINGLE FAMILY', 'RESIDENTIAL CONDO', 'VACANT RURAL LAND',
#        'VACANT RESIDENTIAL LAND', 'DUPLEX', 'CHURCH', 'ZERO LOT LINE',
#        'RESIDENTIAL COMBO/MISC', 'PARSONAGE', 'GREENBELT', 'MOBILE HOME',
#        'PARKING LOT', 'CLUB/UNION HALL/LODGE', 'TRIPLEX',
#        'VACANT ZONED MULTI FAMILY', 'SPLIT CLASS', 'CONDO', 'QUADPLEX',
#        'LIGHT MANUFACTURING', 'FOREST', 'CONVENIENCE MARKET WITHOUT GAS',
#        'DORMITORY/BOARDING HOUSE', 'DAY CARE CENTER',
#        'METRO OTHER THAN OFC, SCHOOL,HOSP, OR PARK',
#        'TERMINAL/DISTRIBUTION WAREHOUSE', 'NIGHTCLUB/LOUNGE',
#        'RESTURANT/CAFETERIA', 'VACANT COMMERCIAL LAND',
#        'CONDOMINIUM OFC  OR OTHER COM CONDO', 'STRIP SHOPPING CENTER',
#        'VACANT RESIENTIAL LAND', 'APARTMENT: LOW RISE (BUILT SINCE 1960)',
#        'ONE STORY GENERAL RETAIL STORE', 'NON-PROFIT CHARITABLE SERVICE',
#        'SMALL SERVICE SHOP', 'MORTUARY/CEMETERY'], dtype=object)

# %%
df['LandUse'].str.contains()

# %%
pd.set_option('display.max.row', 20)

# %%
df
# Out:
#        UniqueID           ParcelID                  LandUse  \
# 0           2045   007 00 0 125.00            SINGLE FAMILY
# 1          16918   007 00 0 130.00            SINGLE FAMILY
# 2          54582   007 00 0 138.00            SINGLE FAMILY
# 3          43070   007 00 0 143.00            SINGLE FAMILY
# 4          22714   007 00 0 149.00            SINGLE FAMILY
# ...          ...               ...                      ...
# 56472      30469  188 10 0A 101.00            SINGLE FAMILY
# 56473      27707  188 10 0A 107.00            SINGLE FAMILY
# 56474      52709  188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 56475      54042  188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress   SaleDate  SalePrice  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000
# ...

# %%
df.describe()
# Out:
#           SalePrice    Acreage      LandValue  BuildingValue     TotalValue  \
# count  2.120000e+02  13.000000      13.000000      13.000000      13.000000
# mean   1.310445e+06  18.900769   61970.538462   63269.230769  142293.615385
# std    1.752724e+06  20.467634   52370.157336  168505.530990  216866.207700
# min    1.400000e+04   1.280000    2195.000000       0.000000    2195.000000
# 25%    1.787500e+05   5.450000   11024.000000       0.000000   12819.000000
# 50%    3.072675e+05   7.750000   58320.000000       0.000000  105000.000000
# 75%    4.062500e+06  27.820000   99195.000000   40000.000000  128200.000000
# max    4.250000e+06  68.790000  167919.000000  617000.000000  824070.000000
#
#          YearBuilt  Bedrooms  FullBath  HalfBath
# count     5.000000  5.000000  5.000000  5.000000
# mean   1946.600000  3.400000  1.800000  0.200000
# std      29.971653  1.140175  1.788854  0.447214
# min    1918.000000  2.000000  1.000000  0.000000
# ...

# %%
df
# Out:
#                                  LandUse                    PropertyAddress  \
# 0    GREENBELT/RES_x000D_\nGRRENBELT/RES   144 SCENIC VIEW  RD, OLD HICKORY
# 1    GREENBELT/RES_x000D_\nGRRENBELT/RES   142 SCENIC VIEW  RD, OLD HICKORY
# 2                                  CONDO       724  DUE WEST AVE N, MADISON
# 3                                  CONDO    428 B  E PALESTINE AVE, MADISON
# 4                              GREENBELT           1833  HUDSON RD, MADISON
# ..                                   ...                                ...
# 282  CONDOMINIUM OFC  OR OTHER COM CONDO  6901  LENOX VILLAGE DR, NASHVILLE
# 291  CONDOMINIUM OFC  OR OTHER COM CONDO      6971  SUNNYWOOD DR, NASHVILLE
# 292  CONDOMINIUM OFC  OR OTHER COM CONDO      6965 SUNNYWOOD  DR, NASHVILLE
# 293                                CONDO  8121  LENOX CREEKSIDE DR, ANTIOCH
# 294                                CONDO  8121  LENOX CREEKSIDE DR, ANTIOCH
#
# ...
